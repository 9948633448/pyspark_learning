-- %% [markdown]
-- ###create database

-- %%
create database sales;

-- %% [markdown]
-- ###create table

-- %%
create table Stores
(
    store_id INT,
    store_name Varchar(200)
);

-- %%
Insert into stores
values
(1,'store_xyz'),
(2,'store_abc');

-- %%
select * from stores

-- %% [markdown]
-- ###Drop

-- %%
drop table stores

-- %%
select * from stores

-- %% [markdown]
-- Read data from file stored in catalog

-- %%
CREATE TABLE Employee AS
SELECT *
FROM read_files(
    '/Volumes/hybrid_workspace/default/sra1csvfile',
    format => 'csv',
    header => true
);

-- %%
select * from Employee

-- %% [markdown]
-- ###drop

-- %%
drop table employee

-- %% [markdown]
-- ### Truncate

-- %%
truncate table employee;
select * from employee

-- %% [markdown]
-- ### Alter

-- %%
ALTER TABLE employee 
ADD COLUMN salary INT;
select * from employee

-- %%
ALTER TABLE hybrid_workspace.default.employee SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

-- %%
ALTER TABLE employee
rename column salaries to wages;
select * from employee

-- %%
Alter table employee
rename column salary to salaries;
select * from employee
